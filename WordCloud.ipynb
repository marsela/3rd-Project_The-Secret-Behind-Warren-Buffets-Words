# %% [markdown]
# # Word Cloud From Some Annual Reports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import data
dataset = pd.read_csv('complete.csv')
response = pd.read_csv('return_plus.csv') #col = 8, 9 <-original 9 and 10

# %%
#Cleaning the text
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\volak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Annual Report from 2016

# %%
review= re.sub('[^a-zA-Z]',' ', dataset['Content'][39])
review = review.lower()
review = review.split() 
#ps=PorterStemmer()
#review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
review = ' '.join(review)

# %%
##### Generate A Word Cloud for one year
from os import path
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
  
# %matplotlib inline
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate(review)
plt.title("2016 Annual Report")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Annual Report from 2006

# %%
review= re.sub('[^a-zA-Z]',' ', dataset['Content'][29])
review = review.lower()
review = review.split() 
#ps=PorterStemmer()
#review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
review = ' '.join(review)

# %%
##### Generate A Word Cloud for one year
from os import path
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
  
# %matplotlib inline
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate(review)
plt.title("2006 Annual Report")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Annual Report from 1996

# %%
review= re.sub('[^a-zA-Z]',' ', dataset['Content'][19])
review = review.lower()
review = review.split() 
#ps=PorterStemmer()
#review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
review = ' '.join(review)

# %%
##### Generate A Word Cloud for one year
from os import path
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
  
# %matplotlib inline
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate(review)
plt.title("1996 Annual Report")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Annual Report from 1987

# %%
review= re.sub('[^a-zA-Z]',' ', dataset['Content'][10])
review = review.lower()
review = review.split() 
#ps=PorterStemmer()
#review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
review = ' '.join(review)

# %%
##### Generate A Word Cloud for one year
from os import path
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
  
# %matplotlib inline
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate(review)
plt.title("1987 Annual Report")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
